# %%
import pandas as pd
df=pd.read_csv("D:\\AI course\\datasets\\population.csv")

# %%
df.head()
# Out:
#   Country name  Year  Population  Population of children under the age of 1  \
# 0  Afghanistan  1950     7480464                                   301735.0
# 1  Afghanistan  1951     7571542                                   299368.0
# 2  Afghanistan  1952     7667534                                   305393.0
# 3  Afghanistan  1953     7764549                                   311574.0
# 4  Afghanistan  1954     7864289                                   317584.0
#
#    Population of children under the age of 5  \
# 0                                    1248282
# 1                                    1246857
# 2                                    1248220
# 3                                    1254725
# 4                                    1267817
#
#    Population of children under the age of 15  Population under the age of 25  \
# 0                                     3068855                         4494349
# ...

# %%
df["Country name"].values
# Out:
# array(['Afghanistan', 'Afghanistan', 'Afghanistan', ..., 'Zimbabwe',
#        'Zimbabwe', 'Zimbabwe'], dtype=object)

# %%
df["Country name"].value_counts()
# Out:
# Country name
# Afghanistan      72
# Oman             72
# Netherlands      72
# New Caledonia    72
# New Zealand      72
#                  ..
# Guatemala        72
# Guernsey         72
# Guinea           72
# Guinea-Bissau    72
# Zimbabwe         72
# Name: count, Length: 254, dtype: int64

# %%
for i in df["Country name"].unique():
    print (i)
# Out:
# Afghanistan
# Africa (UN)
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Anguilla
# Antigua and Barbuda
# Argentina
# Armenia
# Aruba
# Asia (UN)
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bonaire Sint Eustatius and Saba
# Bosnia and Herzegovina
# Botswana
# Brazil
# British Virgin Islands
# Brunei
# Bulgaria
# Burkina Faso
# Burundi
# Cambodia
# Cameroon
# Canada
# Cape Verde
# Cayman Islands
# Central African Republic
# Chad
# Chile
# China
# Colombia
# Comoros
# Congo
# Cook Islands
# Costa Rica
# Cote d'Ivoire
# Croatia
# Cuba
# Curacao
# Cyprus
# Czechia
# Democratic Republic of Congo
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# East Timor
# Ecuador
# Egypt
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Eswatini
# Ethiopia
# Europe (UN)
# Falkland Islands
# Faroe Islands
# Fiji
# Finland
# France
# French Guiana
# French Polynesia
# Gabon
# ...

# %%
df.head()
# Out:
#   Country name  Year  Population  Population of children under the age of 1  \
# 0  Afghanistan  1950     7480464                                   301735.0
# 1  Afghanistan  1951     7571542                                   299368.0
# 2  Afghanistan  1952     7667534                                   305393.0
# 3  Afghanistan  1953     7764549                                   311574.0
# 4  Afghanistan  1954     7864289                                   317584.0
#
#    Population of children under the age of 5  \
# 0                                    1248282
# 1                                    1246857
# 2                                    1248220
# 3                                    1254725
# 4                                    1267817
#
#    Population of children under the age of 15  Population under the age of 25  \
# 0                                     3068855                         4494349
# ...

# %%
afg=df[df["Country name"]=="Afghanistan"]

# %%
afg.head()
# Out:
#   Country name  Year  Population  Population of children under the age of 1  \
# 0  Afghanistan  1950     7480464                                   301735.0
# 1  Afghanistan  1951     7571542                                   299368.0
# 2  Afghanistan  1952     7667534                                   305393.0
# 3  Afghanistan  1953     7764549                                   311574.0
# 4  Afghanistan  1954     7864289                                   317584.0
#
#    Population of children under the age of 5  \
# 0                                    1248282
# 1                                    1246857
# 2                                    1248220
# 3                                    1254725
# 4                                    1267817
#
#    Population of children under the age of 15  Population under the age of 25  \
# 0                                     3068855                         4494349
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(afg["Year"], afg["Population"])

# %%
df.columns
# Out:
# Index(['Country name', 'Year', 'Population',
#        'Population of children under the age of 1',
#        'Population of children under the age of 5',
#        'Population of children under the age of 15',
#        'Population under the age of 25', 'Population aged 15 to 64 years',
#        'Population older than 15 years', 'Population older than 18 years',
#        'Population at age 1', 'Population aged 1 to 4 years',
#        'Population aged 5 to 9 years', 'Population aged 10 to 14 years',
#        'Population aged 15 to 19 years', 'Population aged 20 to 29 years',
#        'Population aged 30 to 39 years', 'Population aged 40 to 49 years',
#        'Population aged 50 to 59 years', 'Population aged 60 to 69 years',
#        'Population aged 70 to 79 years', 'Population aged 80 to 89 years',
#        'Population aged 90 to 99 years', 'Population older than 100 years',
#        'population__all__20_24__records', 'population__all__25_29__records',
# ...

# %%
req=df[["Country name","Year","Population", "Population of children under the age of 15","Population aged 15 to 64 years"]]

# %%
dict_= {"Country name":"country", "Population": "pop","Population of children under the age of 15": "pop under 15",
        "Population aged 15 to 64 years": "pop between 15-64"}

# %%
req.rename(columns=dict_, inplace=True)
# Out:
# C:\Users\HARMAN\AppData\Local\Temp\ipykernel_13920\2425757969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   req.rename(columns=dict_, inplace=True)

# %%
req.head()
# Out:
#        country  Year      pop  pop under 15  pop between 15-64
# 0  Afghanistan  1950  7480464       3068855            4198587
# 1  Afghanistan  1951  7571542       3105444            4250002
# 2  Afghanistan  1952  7667534       3145070            4303436
# 3  Afghanistan  1953  7764549       3186382            4356242
# 4  Afghanistan  1954  7864289       3231060            4408474

# %%
req["pop over 65"]=req["pop"]- (req["pop under 15"]+req["pop between 15-64"])
# Out:
# C:\Users\HARMAN\AppData\Local\Temp\ipykernel_13920\1746539889.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   req["pop over 65"]=req["pop"]- (req["pop under 15"]+req["pop between 15-64"])

# %%
# Define a function plot_population(frame, country) that takes the dataframe
# df and the name of one of its countries and returns a line chart of its total 
# population (an annual time series). For example, the this code produces the following figure:

# %%
def plot_population(df, c):
    required=df[df["country"]==c]
    plt.plot(required["Year"], required["pop"])
    plt.title(c)
    plt.xlabel("Year")
    plt.ylabel("Population change")
    plt.grid(True)
    plt.yticks(ticks= [50000000, 100000000, 150000000, 200000000, 250000000, 300000000],labels=["50M", "100M", "150M", "200M", "250M", "300M"])
    plt.show()

# %%
plot_population(req, "Pakistan")

# %%
plot_population(req, "India")

# %%
plot_population(req, "Indonesia")

# %%
plot_population(req, "Egypt")

# %%
plot_population(req, "Turkey")

# %%
countries=req["country"].values
if "United Arab Emirates" in countries:
    print("It is present in dataset")
else:
    print("It is not here")
# Out:
# It is present in dataset

# %%
#Define a function plot_populations(frame, countries) that takes dataframe df and a list of countries 
#and returns a time-series plotting total population for those countries.

# %%
def plot_lists(df, list_):
    for i in list_:
        required= df[df["country"]==i]
        plt.plot(required["Year"], required["pop"])
        plt.title("Population Comparison")
        plt.xlabel("Year")
        plt.ylabel("Population")
        plt.legend(list_)
        plt.grid(True)
        plt.yticks(ticks= [50000000, 100000000, 150000000, 200000000, 250000000, 300000000],labels=["50M", "100M", "150M", "200M", "250M", "300M"])

# %%
plot_lists(req, ["Pakistan", "Albania", "Indonesia"])

# %%
plot_lists(req, ["India", "China", "Pakistan"])

# %%
plot_lists(req, ["South Korea", "China", "Japan"])

# %%
req.head()
# Out:
#        country  Year      pop  pop under 15  pop between 15-64  pop over 65
# 0  Afghanistan  1950  7480464       3068855            4198587       213022
# 1  Afghanistan  1951  7571542       3105444            4250002       216096
# 2  Afghanistan  1952  7667534       3145070            4303436       219028
# 3  Afghanistan  1953  7764549       3186382            4356242       221925
# 4  Afghanistan  1954  7864289       3231060            4408474       224755

# %%
req.isnull().sum()
# Out:
# country              0
# Year                 0
# pop                  0
# pop under 15         0
# pop between 15-64    0
# pop over 65          0
# dtype: int64

# %%
def plot_ages(df, c):
    filtered= df.loc[df["country"]==c].copy()
    bar_width=0.5
    years=filtered["Year"]
    fig, ax=plt.subplots(figsize=(10,7))
    #plotting the bars
    ax.bar(years, filtered["pop under 15"], bar_width, label="under 15")
    ax.bar(years, filtered["pop between 15-64"], bar_width, bottom=filtered["pop under 15"], label="pop 15-64")
    ax.set_yticks([50000000, 100000000, 150000000, 200000000, 250000000, 300000000])
    ax.set_yticklabels(['50M', '100M', '150M', '200M', '250M', '300M'])
    ax.set_title("Population by age groups")
    ax.set_xlabel("Year")
    ax.set_ylabel("Population")
    ax.legend()
    ax.grid(True)

# %%
plot_ages(req, "India")

# %%
plot_ages(req,  "Pakistan")

# %%
def plot_ages(df, c):
    filtered= df.loc[df["country"]==c].copy()
    bar_width=0.5
    years=filtered["Year"]
    fig, ax=plt.subplots(figsize=(10,7))
    #plotting the bars
    ax.bar(years, filtered["pop under 15"], bar_width, label="under 15")
    ax.bar(years, filtered["pop between 15-64"], bar_width, bottom=filtered["pop under 15"], label="pop 15-64")
    ax.bar(years, filtered["pop over 65"], bar_width, bottom= filtered["pop under 15"]+filtered["pop between 15-64"], label="pop over 65")
    ax.set_yticks([50000000, 100000000, 150000000, 200000000, 250000000, 300000000])
    ax.set_yticklabels(['50M', '100M', '150M', '200M', '250M', '300M'])
    ax.set_title("Population by age groups")
    ax.set_xlabel("Year")
    ax.set_ylabel("Population")
    ax.legend()
    ax.grid(True)

# %%
plot_ages(req, "Indonesia")

# %%
req.head()
# Out:
#        country  Year      pop  pop under 15  pop between 15-64  pop over 65
# 0  Afghanistan  1950  7480464       3068855            4198587       213022
# 1  Afghanistan  1951  7571542       3105444            4250002       216096
# 2  Afghanistan  1952  7667534       3145070            4303436       219028
# 3  Afghanistan  1953  7764549       3186382            4356242       221925
# 4  Afghanistan  1954  7864289       3231060            4408474       224755

# %%
req["under 15%"]=(req["pop under 15"]/req["pop"])*100
# Out:
# C:\Users\HARMAN\AppData\Local\Temp\ipykernel_13920\3735381899.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   req["under 15%"]=(req["pop under 15"]/req["pop"])*100

# %%
req.head()
# Out:
#        country  Year      pop  pop under 15  pop between 15-64  pop over 65  \
# 0  Afghanistan  1950  7480464       3068855            4198587       213022
# 1  Afghanistan  1951  7571542       3105444            4250002       216096
# 2  Afghanistan  1952  7667534       3145070            4303436       219028
# 3  Afghanistan  1953  7764549       3186382            4356242       221925
# 4  Afghanistan  1954  7864289       3231060            4408474       224755
#
#    under 15%
# 0  41.024928
# 1  41.014684
# 2  41.018012
# 3  41.037567
# 4  41.085214

# %%
req["15-64%"]=(req["pop between 15-64"]/req["pop"])*100
req["over 65%"]=(req["pop over 65"]/req["pop"])*100
# Out:
# C:\Users\HARMAN\AppData\Local\Temp\ipykernel_13920\1831539035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   req["15-64%"]=(req["pop between 15-64"]/req["pop"])*100
# C:\Users\HARMAN\AppData\Local\Temp\ipykernel_13920\1831539035.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   req["over 65%"]=(req["pop over 65"]/req["pop"])*100

# %%
req.head()
# Out:
#        country  Year      pop  pop under 15  pop between 15-64  pop over 65  \
# 0  Afghanistan  1950  7480464       3068855            4198587       213022
# 1  Afghanistan  1951  7571542       3105444            4250002       216096
# 2  Afghanistan  1952  7667534       3145070            4303436       219028
# 3  Afghanistan  1953  7764549       3186382            4356242       221925
# 4  Afghanistan  1954  7864289       3231060            4408474       224755
#
#    under 15%     15-64%  over 65%
# 0  41.024928  56.127361  2.847711
# 1  41.014684  56.131261  2.854055
# 2  41.018012  56.125424  2.856564
# 3  41.037567  56.104250  2.858183
# 4  41.085214  56.056867  2.857919

# %%
def plot_percentages(df, c):
    filtered=df[df["country"]==c]
    bar_width=0.5
    years=filtered["Year"]
    fig, ax=plt.subplots(figsize=(10,7))
    ax.bar(years, filtered["under 15%"], bar_width, label="under 15%")
    ax.bar(years, filtered["15-64%"], bar_width, bottom=filtered["under 15%"], label="15-64 %")
    ax.bar(years, filtered["over 65%"], bar_width, bottom=filtered["under 15%"]+filtered["15-64%"], label="over 65%")
    ax.set_title("Population by age groups")
    ax.set_xlabel("Year")
    ax.set_ylabel("Population")
    ax.legend()
    ax.grid(True)

# %%
plot_percentages(req, "Pakistan")

# %%
plot_percentages(req,"India")

# %%
plot_percentages(req, "Albania")

# %%
filtered.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 filtered.head()
#
# NameError: name 'filtered' is not defined

# %%
bar_width
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 bar_width
#
# NameError: name 'bar_width' is not defined
